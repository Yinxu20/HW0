# %% [markdown]
# <center><h1>INF-552 Lab 0</h1></center>
# <br>
# <center><font size="4">Introduction to Basic Development Tools</font></center>

# %% [markdown]
# Yin Xu

# %% [markdown]
# USC ID:7081882362

# %% [markdown]
# Github username:Yinxu20

# %% [markdown]
# ### Rules

# %% [markdown]
# 1. Please read the instructions and problem prompts **carefully**.
# 2. This lab is to give you some basic APIs of numpy, pandas and scikit-learn. Besides, some topics such as how to make your jupyter notebook be a more efficient developing tools, how to use git and GitHub will also be covered. The lab is to be done individually. You may talk to your fellow classmates about general issues ("Remind me again: Which API should I used for doing group by operation to a data set") but about the specifies of how to do these exercises.
# 3. Along with a similar vein, you can ask the TA for help, but ask questions about **concepts** but not ask the TA to help you debug your code. The TA is here to help, but not to do the work for you.
# 4. You are welcome to use the class resources and the Internet.
# 5. Playing with variations. Solve one problems, and then copy the code to a new cell and play around with it. Doing this is the single most important thing when learning programming.
# 6. This lab will not be graded but the content is highly related to your future programming assignments. So, treat it wisely.
# 7. All the content having been gone though in the week 1 discussion is just a snapshot of the most basic concepts. **You need to keep study more about Git, GitHub, Pandas, Numpy and Scikit-Learn in order to finish your programming assignments successfully.**
# 8. Have fun!

# %% [markdown]
# ### Setup Development Environment

# %% [markdown]
# There are many ways to setup the environment. But, I do recommend a simple idea that is using the Anaconda, which is a pre-build python environment with bundles of useful packages.
#
# **To download the Anaconda, go to the following website:
# https://www.anaconda.com/distribution/**. Download the correct version based on your operating system and install it step by step.
#
# Then, **configure your PATH environment variable** to make the conda command work. The following command is an easy way to test whether your configuration is correct. If it is, you will see something as like as the sample output.
#
# > **command:**
# >
# > conda --version
# >
# > **sample output:**
# >
# > conda 4.6.12
#
# **Finally, download this jupyter notebook file,** then change the working directory to where its location in terminal, and type the following command to open the jupter notebook and finish the lab.
#
# > **command:**
# > jupyter notebook

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Pandas

# %% [markdown]
# #### The read_csv() Method

# %% [markdown]
# First, read the documentation about the *read_csv()* method in Pandas (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html). Then, try to read data from file Salaries.csv to a dataframe, make the column playerID in the csv file as the index column and the first row as the header. Also, skip the second row when reading the file.

# %%
df = pd.read_csv("Salaries.csv",header=0,index_col='playerID',skiprows=[1])
print(df)
# Out:
#            yearID teamID lgID    salary
# playerID
# bedrost01    1985    ATL   NL    550000
# benedbr01    1985    ATL   NL    545000
# campri01     1985    ATL   NL    633333
# ceronri01    1985    ATL   NL    625000
# chambch01    1985    ATL   NL    800000
# ...           ...    ...  ...       ...
# treinbl01    2015    WAS   NL    512800
# ugglada01    2015    WAS   NL    507500
# werthja01    2015    WAS   NL  21000000
# zimmejo02    2015    WAS   NL  16500000
# zimmery01    2015    WAS   NL  14000000
#
# [25574 rows x 4 columns]

# %% [markdown]
# #### Indexing and Selecting Data

# %% [markdown]
# Select the id of the players who are registered in ATL and HOU and whose salary is higher than one million.

# %%
df = pd.read_csv("Salaries.csv",header=0,index_col='playerID',skiprows=[1])

result = df[(df.salary > 1000000) & (df.teamID == 'ATL')].index.tolist()+ df[(df.salary > 1000000) & (df.teamID == 'HOU')].index.tolist()
print(result)
# Out:
# ['hornebo01', 'murphda05', 'suttebr01', 'hornebo01', 'murphda05', 'suttebr01', 'griffke01', 'murphda05', 'suttebr01', 'murphda05', 'suttebr01', 'murphda05', 'suttebr01', 'esaskni01', 'murphda05', 'smithlo01', 'suttebr01', 'whitter01', 'breamsi01', 'esaskni01', 'gantro01', 'leibrch01', 'pendlte01', 'smithlo01', 'berenju01', 'bielemi01', 'breamsi01', 'esaskni01', 'gantro01', 'glavito02', 'leibrch01', 'nixonot01', 'penaal01', 'pendlte01', 'smithlo01', 'smoltjo01', 'treadje01', 'blausje01', 'breamsi01', 'gantro01', 'glavito02', 'justida01', 'maddugr01', 'nixonot01', 'pendlte01', 'sandede02', 'smithpe02', 'smoltjo01', 'averyst01', 'blausje01', 'gantro01', 'glavito02', 'justida01', 'lemkema01', 'maddugr01', 'mcgrifr01', 'merckke01', 'olsongr01', 'pendlte01', 'sandede02', 'smoltjo01', 'stantmi02', 'averyst01', 'blausje01', 'glavito02', 'grissma02', 'justida01', 'lemkema01', 'maddugr01', 'mcgrifr01', 'merckke01', 'smoltjo01', 'stantmi02', 'averyst01', 'blausje01', 'glavito02', 'grissma02', 'justida01', 'lemkema01', 'maddugr01', 'mcgrifr01', 'smoltjo01', 'wohlema01', 'blausje01', 'glavito02', 'jonesch06', 'kleskry01', 'lemkema01', 'loftoke01', 'lopezja01', 'maddugr01', 'mcgrifr01', 'neaglde01', 'smoltjo01', 'wohlema01', 'galaran01', 'glavito02', 'jonesch06', 'kleskry01', 'lopezja01', 'maddugr01', 'neaglde01', 'smoltjo01', 'weisswa01', 'willige02', 'wohlema01', 'boonebr01', 'galaran01', 'glavito02', 'jonesch06', 'jordabr01', 'kleskry01', 'lopezja01', 'maddugr01', 'nixonot01', 'remlimi01', 'smoltjo01', 'weisswa01', 'willige02', 'wohlema01', 'galaran01', 'glavito02', 'jonesan01', 'jonesch06', 'jordabr01', 'joynewa01', 'lopezja01', 'maddugr01', 'mulhote01', 'remlimi01', 'sandere02', 'seaneru01', 'smoltjo01', 'verasqu01', 'weisswa01', 'brognri01', 'burkejo03', 'glavito02', 'jonesan01', 'jonesch06', 'jordabr01', 'ligteke01', 'lopezja01', 'maddugr01', 'martida01', 'millwke01', 'remlimi01', 'rockejo01', 'smoltjo01', 'surhobj01', 'verasqu01', 'blanche01', 'castivi02', 'glavito02', 'jonesan01', 'jonesch06', 'ligteke01', 'lopezal02', 'lopezja01', 'maddugr01', 'martida01', 'millwke01', 'remlimi01', 'sheffga01', 'smoltjo01', 'surhobj01', 'blanche01', 'byrdpa01', 'castivi02', 'furcara01', 'hamptmi01', 'jonesan01', 'jonesch06', 'lopezja01', 'maddugr01', 'ortizru01', 'sheffga01', 'smoltjo01', 'alfonan01', 'byrdpa01', 'drewjd01', 'furcara01', 'hamptmi01', 'jonesan01', 'jonesch06', 'marreel01', 'ortizru01', 'smoltjo01', 'thomsjo01', 'furcara01', 'gilesma01', 'hamptmi01', 'hudsoti01', 'jonesan01', 'jonesch06', 'kolbda01', 'martito02', 'reitsch01', 'smoltjo01', 'thomsjo01', 'gilesma01', 'hamptmi01', 'hudsoti01', 'jonesan01', 'jonesch06', 'ramirho01', 'reitsch01', 'renteed01', 'smoltjo01', 'sosajo02', 'thomsjo01', 'gonzami02', 'hamptmi01', 'hudsoti01', 'jonesan01', 'jonesch06', 'renteed01', 'smoltjo01', 'soriara01', 'wickmbo01', 'wilsocr03', 'diazma02', 'glavito02', 'gonzami02', 'hamptmi01', 'hudsoti01', 'infanom01', 'jonesch06', 'kotsama01', 'ohmanwi01', 'smoltjo01', 'soriara01', 'teixema01', 'anderga01', 'diazma02', 'francje02', 'gonzami02', 'hudsoti01', 'infanom01', 'johnske05', 'jonesch06', 'kawakke01', 'kotchca01', 'lowede01', 'mccanbr01', 'rossda01', 'soriara01', 'vazquja01', 'cabreme01', 'diazma02', 'glaustr01', 'hudsoti01', 'infanom01', 'jonesch06', 'kawakke01', 'lowede01', 'mccanbr01', 'mclouna01', 'moylape01', 'rossda01', 'saitota01', 'wagnebi02', 'gonzaal02', 'hinsker01', 'hudsoti01', 'jonesch06', 'jurrjja01', 'linebsc01', 'lowede01', 'mccanbr01', 'mclouna01', 'moylape01', 'pradoma01', 'rossda01', 'sherrge01', 'ugglada01', 'bournmi01', 'diazma02', 'hinsker01', 'hudsoti01', 'jonesch06', 'jurrjja01', 'mccanbr01', 'oflaher01', 'pradoma01', 'rossda01', 'ugglada01', 'heywaja01', 'hudsoti01', 'johnsch05', 'johnsre02', 'lairdge01', 'maholpa01', 'mccanbr01', 'medlekr01', 'oflaher01', 'ugglada01', 'uptonbj01', 'uptonju01', 'doumiry01', 'floydga01', 'freemfr01', 'heywaja01', 'johnsch05', 'kimbrcr01', 'lairdge01', 'minormi01', 'santaer01', 'ugglada01', 'up ...

# %% [markdown]
# #### The describe() Method

# %% [markdown]
# Calculate the standard Deviation, first quartile, medium, third quartile, mean, maximum, minimum of the salary in team ATL.

# %%
result = df[df.teamID == 'ATL']
result.describe()
# Out:
#             yearID        salary
# count   885.000000  8.850000e+02
# mean   1999.725424  2.207749e+06
# std       8.766470  3.434320e+06
# min    1985.000000  6.000000e+04
# 25%    1992.000000  3.000000e+05
# 50%    1999.000000  6.000000e+05
# 75%    2007.000000  2.400000e+06
# max    2015.000000  1.606180e+07

# %% [markdown]
# #### The iterrows() Method

# %% [markdown]
# Create a Python dictionary object whose keys are the headers of the dataframe created in the read_csv() exercise and values are Python list objects that contain data corresponding to the headers. (Here, use the iterrows method to iterate each row of the dataframe and copy it to a dictionary. However, there is a easier way. Learn how the to_dict() method works by yourself later)

# %%
df = pd.read_csv("Salaries.csv",header=0,index_col='playerID',skiprows=[1])
dic = {}
for row in df.iterrows():
    dic[row[0]] = row[1]

print(dic)
# Out:
# {'bedrost01': yearID      1995
# teamID       ATL
# lgID          NL
# salary    750000
# Name: bedrost01, dtype: object, 'benedbr01': yearID      1989
# teamID       ATL
# lgID          NL
# salary    395000
# Name: benedbr01, dtype: object, 'campri01': yearID      1986
# teamID       ATL
# lgID          NL
# salary    600000
# Name: campri01, dtype: object, 'ceronri01': yearID      1992
# teamID       MON
# lgID          NL
# salary    230000
# Name: ceronri01, dtype: object, 'chambch01': yearID      1986
# teamID       ATL
# lgID          NL
# salary    769452
# Name: chambch01, dtype: object, 'dedmoje01': yearID      1988
# teamID       CLE
# lgID          AL
# salary    350000
# Name: dedmoje01, dtype: object, 'forstte01': yearID      1986
# teamID       CAL
# lgID          AL
# salary    170000
# Name: forstte01, dtype: object, 'garbege01': yearID      1988
# teamID       KCA
# lgID          AL
# salary    500000
# Name: garbege01, dtype: object, 'harpete01': yearID      1987
# teamID       DET
# lgID          AL
# salary    425000
# Name: harpete01, dtype: object, 'hornebo01': yearID      1988
# teamID       SLN
# lgID          NL
# salary    950000
# Name: hornebo01, dtype: object, 'hubbagl01': yearID      1988
# teamID       OAK
# lgID          AL
# salary    425000
# Name: hubbagl01, dtype: object, 'mahleri01': yearID      1990
# teamID       CIN
# lgID          NL
# salary    790000
# Name: mahleri01, dtype: object, 'mcmurcr01': yearID      1995
# teamID       HOU
# lgID          NL
# salary    275000
# Name: mcmurcr01, dtype: object, 'mumphje01': yearID      1988
# teamID       CHN
# lgID          NL
# salary    608000
# Name: mumphje01, dtype: object, 'murphda05': yearID      1993
# teamID       COL
# lgID          NL
# salary    200000
# Name: murphda05, dtype: object, 'oberkke01': yearID      1991
# teamID       HOU
# lgID          NL
# salary    675000
# Name: oberkke01, dtype: object, 'perezpa01': yearID       1991
# teamID        NYA
# lgID           AL
# salary    2133333
# Name: perezpa01, dtype: object, 'perryge01': yearID      1995
# teamID       SLN
# lgID          NL
# salary    299000
# Name: perryge01, dtype: object, 'ramirra01': yearID      1992
# teamID       HOU
# lgID          NL
# salary    400000
# Name: ramirra01, dtype: object, 'suttebr01': yearID       1990
# teamID        ATL
# lgID           NL
# salary    1729167
# Name: suttebr01, dtype: object, 'washicl01': yearID      1990
# teamID       CAL
# lgID          AL
# salary    675000
# Name: washicl01, dtype: object, 'boddimi01': yearID       1993
# teamID        KCA
# lgID           AL
# salary    2916667
# Name: boddimi01, dtype: object, 'dauerri01': yearID      1985
# teamID       BAL
# lgID          AL
# salary    480000
# Name: dauerri01, dtype: object, 'davisst02': yearID      1994
# teamID       DET
# lgID          AL
# salary    800000
# Name: davisst02, dtype: object, 'dempsri01': yearID      1992
# teamID       BAL
# lgID          AL
# salary    450000
# Name: dempsri01, dtype: object, 'dwyerji01': yearID      1990
# teamID       MIN
# lgID          AL
# salary    240000
# Name: dwyerji01, dtype: object, 'flanami01': yearID      1992
# teamID       BAL
# lgID          AL
# salary    600000
# Name: flanami01, dtype: object, 'fordda01': yearID      1986
# teamID       BAL
# lgID          AL
# salary    350000
# Name: fordda01, dtype: object, 'grosswa01': yearID     1986
# teamID      OAK
# lgID         AL
# salary    60000
# Name: grosswa01, dtype: object, 'lacyle01': yearID      1987
# teamID       BAL
# lgID          AL
# salary    525000
# Name: lacyle01, dtype: object, 'lynnfr01': yearID      1990
# teamID       SDN
# lgID          NL
# salary    650000
# Name: lynnfr01, dtype: object, 'martide01': yearID      1998
# teamID       ATL
# lgID          NL
# salary    550000
# Name: martide01, dtype: object, 'martiti01': yearID      1986
# teamID       BAL
# lgID          AL
# salary    487078
# Name: martiti01, dtype: object, 'mcgresc01': yearID       1988
# teamID        BAL
# lgID           AL
# salary    1066171
# Name: mcgresc01, dtype: object, 'murraed02': yearID      1997
# teamID       ANA
# lgID          AL
# salary    750000
# Name: murraed02, dtype: object, 'nolanjo01': yearID      1985
# teamID       BAL
# lgID          AL
# salary    341667
# Name: nolanjo01, dtype: object, 'rayfofl01': yearID      1987
# teamID       BAL
# lgID          AL
# salary    248000
# Name: rayfofl01, dtype: object, 'ripkeca01': yearID       2001
# teamID        BAL
# lgID           AL
# salary    6300000
# Name: ripkeca01, dtype: object, 'roeniga01': yearID      1988
# teamID       ATL
# lgID          NL
# salary    380000
# Name: roeniga01, dtype: object, 'sheetla01': yearID      1990
# teamID       DET
# lgID          AL
# salary    670000
# Name: sheetla01, dtype: object, 'shelbjo01': yearID      1991
# teamID       DET
# lgID          AL
# salary    525000
# Name: shelbjo01, dtype: object, 'stewasa01': yearID      1987
# teamID       CLE
# lgID          AL
# salary    175000
# Name: stewasa01, dtype: object, 'youngmi01': yearID      1989
# teamID       CLE
# lgID          AL
# salary    150000
# Name: youngmi01, dtype: object, 'armasto01': yearID      1989
# teamID       CAL
# lgID          AL
# salary    525000
# Name: armasto01, dtype: object, 'barrema02': yearID       1990
# teamID        BOS
# lgID           AL
# salary    1000000
# Name: barrema02, dtype: object, 'boggswa01': yearID      1999
# teamID       TBA
# lgID          AL
# salary    750000
# Name: boggswa01, dtype: object, 'bordiri01': yearID      1986
# teamID       BAL
# lgID          AL
# salary    250000
# Name: bordiri01, dtype: object, 'boydoi01': yearID       1991
# teamID        MON
# lgID           NL
# salary    1500000
# Name: boydoi01, dtype: object, 'bucknbi01': yearID      1989
# teamID       KCA
# lgID          AL
# salary    400000
# Name: bucknbi01, dtype: object, 'clearma01': yearID      1988
# teamID       ML4
# lgID          AL
# salary    535000
# Name: clearma01, dtype: object, 'clemero02': yearID        2005
# teamID         HOU
# lgID            NL
# salary    18000000
# Name: clemero02, dtype: object, 'crawfst01': yearID      1990
# teamID       KCA
# lgID          AL
# salary    375000
# Name: crawfst01, dtype: object, 'easlemi01': yearID      1987
# teamID       PHI
# lgID          NL
# salary    700000
# Name: easlemi01, dtype: object, 'evansdw01': yearID      1991
# teamID       BAL
# lgID          AL
# salary    800000
# Name: evansdw01, dtype: object, 'gedmari01': yearID      1992
# teamID       SLN
# lgID          NL
# salary    200000
# Name: gedmari01, dtype: object, 'gutieja01': yearID      1986
# teamID       BAL
# lgID          AL
# salary    167500
# Name: gutieja01, dtype: object, 'hoffmgl01': yearID      1989
# teamID       CAL
# lgID          AL
# salary    160000
# Name: hoffmgl01, dtype: object, 'hurstbr01': yearID       1993
# teamID        SDN
# lgID           NL
# salary    3000000
# Name: hurstbr01, dtype: object, 'juraked01': yearID      1985
# teamID       BOS
# lgID          AL
# salary    125000
# Name: juraked01, dtype: object, 'kisonbr01': yearID      1985
# teamID       BOS
# lgID          AL
# salary    370000
# Name: kisonbr01, dtype: object, 'milleri01': yearID      1985
# teamID       BOS
# lgID          AL
# salary    275000
# Name: milleri01, dtype: object, 'nichore01': yearID     1987
# teamID      MON
# lgID         NL
# salary    62500
# Name: nichore01, dtype: object, 'nippeal01': yearID      1988
# teamID       CHN
# lgID          NL
# salary    397000
# Name: nippeal01, dtype: object, 'ojedabo01': yearID       1993
# teamID        CLE
# lgID           AL
# salary    1700000
# Name: ojedabo01, dtype: object, 'remyje01': yearID      1985
# teamID       BOS
# lgID          AL
# salary    483333
# Name: remyje01, dtype: object, 'riceji01': yearID       1989
# teamID        BOS
# lgID           AL
# salary    2354748
# Name: riceji01, dtype: object, 'stanlbo01': yearID       1988
# teamID        BOS
# lgID           AL
# salary    1060000
# Name: stanlbo01, dtype: object, 'staplda01': yearID      1986
# teamID       BOS
# lgID          AL
# salary    300000
# Name: staplda01, dtype: object, 'beniqju01': yearID      1988
# teamID       TOR
# lgID          AL
# salary    400000
# Name: beniqju01, dtype: object, 'boonebo01': yearID       1990
# teamID        KCA
# lgID           AL
# salary    1900000
# Name: boonebo01, dtype: object, 'burleri01': yearID      1987
# teamID       BAL
# lgID          AL
# salary    200000
# Name: burleri01, dtype: object, 'candejo01': yearID      1993
# teamID       PIT
# lgID          NL
# salary    760000
# Name: candejo01, dtype: object, 'carewro01': yearID      1985
# teamID       CAL
# lgID          AL
# salary    875000
# Name: carewro01, dtype: object, 'clibust02': yearID     1985
# teamID      CAL
# lgID         AL
# salary    60000
# Name: clibust02, dtype: object, 'corbedo01': yearID      1986
# teamID       CAL
# lgID          AL
# salary    410000
# Name: corbedo01, dtype: object, 'decindo01': yearID       1987
# teamID        CAL
# lgID           AL
# salary    1050000
# Name: decindo01, dtype: object, 'downibr01': yearID      1992
# teamID       TEX
# lgID          AL
# salary    950000
# Name: downibr01, dtype: object, 'forscke01': yearID      1986
# teamID       CAL
# lgID          AL
# salary    100000
# Name: forscke01, dtype: object, 'grichbo01': yearID      1986
# teamID       CAL
# lgID          AL
# salary    500000
# Name: grichbo01, dtype: object, 'hendrge01': yearID      1988
# teamID       CAL
# lgID          AL
# salary    989333
# Name: hendrge01, dtype: object, 'hollaal01': yearID      1987
# teamID       NYA
# lgID          AL
# salary    400000
# Name: hollaal01, dtype: object, 'jacksre01': yearID      1987
# teamID       CAL
# lgID          AL
# salary    525000
# Name: jacksre01, dtype: object, 'jonesru01': yearID      1987
# teamID       CAL
# lgID          AL
# salary    450000
# Name: jonesru01, dtype: object, 'lacorfr01': yearID      1985
# teamID       CAL
# lgID          AL
# salary    346667
# Name: lacorfr01, dtype: object, 'mccaski01': yearID      1996
# teamID       CHA
# lgID          AL
# salary    800000
# Name: mccaski01, dtype: object, 'mooredo01': yearID       1988
# teamID        CAL
# lgID           AL
# salary    1000000
# Name: mooredo01, dtype: object, 'pettiga01': yearID      1993
# teamID       OAK
# lgID          AL
# salary    300000
# Name: pettiga01, dtype: object, 'romanro01': yearID      1986
# teamID       CAL
# lgID          AL
# salary    425000
# Name: romanro01, dtype: object, 'sanchlu01': yearID      1985
# teamID       CAL
# lgID          AL
# salary    340000
# Name: sanchlu01, dtype: object, 'schofdi02': yearID      1996
# teamID       CAL
# lgID          AL
# salary    250000
# Name: schofdi02, dtype: object, 'sconida01': yearID      1985
# teamID       CAL
# lgID          AL
# salary    130000
# Name: sconida01, dtype: object, 'slatoji01': yearID     1986
# teamID      DET
# lgID         AL
# salary    60000
# Name: slatoji01, dtype: object, 'suttodo01': yearID      1988
# teamID       LAN
# lgID          NL
# salary    350000
# Name: suttodo01, dtype: object, 'wilforo01': yearID      1986
# teamID       CAL
# lgID          AL
# salary    416667
# Name: wilforo01, dtype: object, 'wittmi01': yearID       1993
# teamID        NYA
# lgID           AL
# salary    2166667
# Name: wittmi01, dtype: object, 'zahnge01': yearID      1985
# teamID       CAL
# lgID          AL
# salary    550000
# Name: zahnge01, dtype: object, 'agostju01': yearID       1992
# teamID        SLN
# lgID           NL
# salary    1666667
# Name: agostju01, dtype: object, 'baineha01': yearID       2001
# teamID        CHA
# lgID           AL
# salary    1000000
# Name: baineha01, dtype: object, 'bannifl01': yearID      1992
# teamID       TEX
# lgID          AL
# salary    225000
# Name: bannifl01, dtype: object, 'burnsbr01': yearID      1986
# teamID       NYA
# lgID          AL
# salary    750000
# Name: burnsbr01, dtype: object, 'cruzju01': yearID      1986
# teamID       CHA
# lgID          AL
# salary    600000
# Name: cruzju01, dtype: object, 'dotsori01': yearID      1990
# teamID       KCA
# lgID          AL
# salary    550000
# Name: dotsori01, dtype: object, 'fiskca01': yearID       1992
# teamID        CHA
# lgID           AL
# salary    1000000
# Name: fiskca01, dtype: object, 'fletcsc01': yearID      1995
# teamID       DET
# lgID          AL
# salary    250000
# Name: fletcsc01, dtype: object, 'guilloz01': yearID      1999
# teamID       ATL
# lgID          NL
# salary    550000
# Name: guilloz01, dtype: object, 'hairsje01': yearID      1986
# teamID       CHA
# lgID          AL
# salary    156667
# Name: hairsje01, dtype: object, 'hillma01': yearID      1987
# teamID       CHA
# lgID          AL
# salary    275000
# Name: hillma01, dtype: object, 'jamesbo01': yearID      1987
# teamID       CHA
# lgID          AL
# salary    470000
# Name: jamesbo01, dtype: object, 'kittlro01': yearID      1990
# teamID       CHA
# lgID          AL
# salary    550000
# Name: kittlro01, dtype: object, 'lawru01': yearID      1987
# teamID       KCA
# lgID          AL
# salary    300000
# Name: lawru01, dtype: object, 'lollati01': yearID      1986
# teamID       BOS
# lgID          AL
# salary    541250
# Name: lollati01, dtype: object, 'nelsoge01': yearID       1992
# teamID        OAK
# lgID           AL
# salary    1250000
# Name: nelsoge01, dtype: object, 'pacioto01': yearID      1986
# teamID       TEX
# lgID          AL
# salary    201500
# Name: pacioto01, dtype: object, 'salazlu01': yearID      1992
# teamID       CHN
# lgID          NL
# salary    600000
# Name: salazlu01, dtype: object, 'seaveto01': yearID       1986
# teamID        CHA
# lgID           AL
# salary    1132652
# Name: seaveto01, dtype: object, 'spillda01': yearID      1985
# teamID       CHA
# lgID          AL
# salary    390000
# Name: spillda01, dtype: object, 'walkegr01': yearID      1989
# teamID       CHA
# lgID          AL
# salary    718810
# Name: walkegr01, dtype: object, 'bosleth01': yearID      1990
# teamID       TEX
# lgID          AL
# salary    250000
# Name: bosleth01, dtype: object, 'brusswa01': yearID      1986
# teamID       CHN
# lgID          NL
# salary    575000
# Name: brusswa01, dtype: object, 'ceyro01': yearID       1987
# teamID        CHN
# lgID           NL
# salary    1050000
# Name: ceyro01, dtype: object, 'davisjo02': yearID      1990
# teamID       ATL
# lgID          NL
# salary    800000
# Name: davisjo02, dtype: object, 'dernibo01': yearID      1989
# teamID       PHI
# lgID          NL
# salary    400000
# Name: dernibo01, dtype: object, 'durhale01': yearID      1989
# teamID       SLN
# lgID          NL
# salary    175000
# Name: durhale01, dtype: object, 'eckerde01': yearID       1998
# teamID        BOS
# lgID           AL
# salary    1500000
# Name: eckerde01, dtype: object, 'fontera01': yearID      1986
# teamID       CHN
# lgID          NL
# salary    240000
# Name: fontera01, dtype: object, 'frazige01': yearID      1986
# teamID       CHN
# lgID          NL
# salary    633333
# Name: frazige01, dtype: object, 'hebneri01': yearID      1986
# teamID       CHN
# lgID          NL
# salary    100000
# Name: hebneri01, dtype: object, 'lopesda01': yearID      1987
# teamID       HOU
# lgID          NL
# salary    550000
# Name: lopesda01, dtype: object, 'matthga01': yearID      1986
# teamID       CHN
# lgID          NL
# salary    850000
# Name: matthga01, dtype: object, 'morelke01': yearID       1989
# teamID        DET
# lgID           AL
# salary    1483333
# Name: morelke01, dtype: object, 'ruthvdi01': yearID       1986
# teamID        CHN
# lgID           NL
# salary    1050000
# Name: ruthvdi01, dtype: object, 'sandbry01': yearID       1997
# teamID        CHN
# lgID           NL
# salary    3250000
# Name: sandbry01, dtype: object, 'sandesc01': yearID      1996
# teamID       CAL
# lgID          AL
# salary    200000
# Name: sandesc01, dtype: object, 'smithle02': yearID      1997
# teamID       MON
# lgID          NL
# salary    400000
# Name: smithle02, dtype: object, 'sorenla01': yearID      1985
# teamID       CHN
# lgID          NL
# salary    320000
# Name: sorenla01, dtype: object, 'speiech01': yearID      1989
# teamID       SFN
# lgID          NL
# salary    425000
# Name: speiech01, dtype: object, 'sutclri01': yearID      1994
# teamID       SLN
# lgID          NL
# salary    250000
# Name: sutclri01, dtype: object, 'troutst01': yearID      1988
# teamID       SEA
# lgID          AL
# salary    990000
# Name: troutst01, dtype: object, 'woodsga01': yearID      1986
# teamID       CHN
# lgID          NL
# salary    325000
# Name: woodsga01, dtype: object, 'bellbu01': yearID      1988
# teamID       CIN
# lgID          NL
# salary    790909
# Name: bellbu01, dtype: object, 'brownto05': yearID      1995
# teamID       KCA
# lgID          AL
# salary    300000
# Name: brownto05, dtype: object, 'conceda01': yearID      1988
# teamID       CIN
# lgID          NL
# salary    370000
# Name: conceda01, dtype: object, 'foleyto02': yearID      1995
# teamID       MON
# lgID          NL
# salary    160000
# Name: foleyto02, dtype: object, 'francjo01': yearID      2005
# teamID       HOU
# lgID          NL
# salary    700000
# Name: francjo01, dtype: object, 'humeto01': yearID      1987
# teamID       CIN
# lgID          NL
# salary    100000
# Name: humeto01, dtype: object, 'krencwa01': yearID      1986
# teamID       MON
# lgID          NL
# salary    320000
# Name: krencwa01, dtype: object, 'mcgafan01': yearID      1990
# teamID       MON
# lgID          NL
# salary    506000
# Name: mcgafan01, dtype: object, 'milneed01': yearID      1987
# teamID       SFN
# lgID          NL
# salary    490000
# Name: milneed01, dtype: object, 'oestero01': yearID      1990
# teamID       CIN
# lgID          NL
# salary    650000
# Name: oestero01, dtype: object, 'parkeda01': yearID       1991
# teamID        CAL
# lgID           AL
# salary    1600000
# Name: parkeda01, dtype: object, 'pastofr01': yearID     1986
# teamID      MIN
# lgID         AL
# salary    60000
# Name: pastofr01, dtype: object, 'perezto01': yearID      1986
# teamID       CIN
# lgID          NL
# salary    275000
# Name: perezto01, dtype: object, 'powerte01': yearID      1994
# teamID       SEA
# lgID          AL
# salary    500000
# Name: powerte01, dtype: object, 'pricejo02': yearID      1990
# teamID       BAL
# lgID          AL
# salary    325000
# Name: pricejo02, dtype: object, 'redusga01': yearID      1994
# teamID       TEX
# lgID          AL
# salary    500000
# Name: redusga01, dtype: object, 'rosepe01': yearID       1986
# teamID        CIN
# lgID           NL
# salary    1000000
# Name: rosepe01, dtype: object, 'sotoma01': yearID       1988
# teamID        CIN
# lgID           NL
# salary    1200000
# Name: sotoma01, dtype: object, 'stupejo01': yearID      1985
# teamID       CIN
# lgID          NL
# salary    250000
# Name: stupejo01, dtype: object, 'tibbsja01': yearID      1990
# teamID       BAL
# lgID          AL
# salary    335000
# Name: tibbsja01, dtype: object, 'vangoda01': yearID      1986
# teamID       CIN
# lgID          NL
# salary    150000
# Name: vangoda01, dtype: object, 'venabma01': yearID      2010
# teamID       SDN
# lgID          NL
# salary    412800
# Name: venabma01, dtype: object, 'ayalabe01': yearID      1985
# teamID       CLE
# lgID          AL
# salary    303333
# Name: ayalabe01, dtype: object, 'bandoch01': yearID      1988
# teamID       CLE
# lgID          AL
# salary    325000
# Name: bandoch01, dtype: object, 'bernato01': yearID      1991
# teamID       DET
# lgID          AL
# salary    525000
# Name: bernato01, dtype: object, 'blylebe01': yearID      1992
# teamID       CAL
# lgID          AL
# salary    900000
# Name: blylebe01, dtype: object, 'butlebr01': yearID       1997
# teamID        LAN
# lgID           NL
# salary    1733304
# Name: butlebr01, dtype: object, 'camacer01': yearID      1990
# teamID       SFN
# lgID          NL
# salary    150000
# Name: camacer01, dtype: object, 'cartejo01': yearID       1998
# teamID        BAL
# lgID           AL
# salary    3151380
# Name: cartejo01, dtype: object, 'easteja01': yearID      1987
# teamID       CLE
# lgID          AL
# salary    370000
# Name: easteja01, dtype: object, 'fischmi01': yearID      1986
# teamID       NYA
# lgID          AL
# salary    200000
# Name: fischmi01, dtype: object, 'francju01': yearID       2007
# teamID        NYN
# lgID           NL
# salary    1150000
# Name: francju01, dtype: object, 'garlawa01': yearID      1986
# teamID       CLE
# lgID          AL
# salary    215000
# Name: garlawa01, dtype: object, 'hallme01': yearID      1996
# teamID       SFN
# lgID          NL
# salary    120000
# Name: hallme01, dtype: object, 'hargrmi01': yearID      1985
# teamID       CLE
# lgID          AL
# salary    458333
# Name: hargrmi01, dtype: object, 'heatone01': yearID      1993
# teamID       NYA
# lgID          AL
# salary    250000
# Name: heatone01, dtype: object, 'jacobbr01': yearID      1992
# teamID       CLE
# lgID          AL
# salary    550000
# Name: jacobbr01, dtype: object, 'ruhleve01': yearID     1986
# teamID      CAL
# lgID         AL
# salary    60000
# Name: ruhleve01, dtype: object, 'tablepa01': yearID      1992
# teamID       TOR
# lgID          AL
# salary    900000
# Name: tablepa01, dtype: object, 'thornan01': yearID       1988
# teamID        CLE
# lgID           AL
# salary    1100000
# Name: thornan01, dtype: object, 'vukovge01': yearID      1985
# teamID       CLE
# lgID          AL
# salary    375000
# Name: vukovge01, dtype: object, 'waddeto01': yearID      1986
# teamID       CLE
# lgID          AL
# salary    270000
# Name: waddeto01, dtype: object, 'berenju01': yearID       1992
# teamID        ATL
# lgID           NL
# salary    1200000
# Name: berenju01, dtype: object, 'bergmda01': yearID      1992
# teamID       DET
# lgID          AL
# salary    375000
# Name: bergmda01, dtype: object, 'brookto01': yearID      1990
# teamID       CLE
# lgID          AL
# salary    425000
# Name: brookto01, dtype: object, 'castima02': yearID     1985
# teamID      DET
# lgID         AL
# salary    76000
# Name: castima02, dtype: object, 'evansda01': yearID      1989
# teamID       ATL
# lgID          NL
# salary    415000
# Name: evansda01, dtype: object, 'gibsoki01': yearID       1995
# teamID        DET
# lgID           AL
# salary    1300000
# Name: gibsoki01, dtype: object, 'grubbjo01': yearID      1987
# teamID       DET
# lgID          AL
# salary    365000
# Name: grubbjo01, dtype: object, 'hernawi01': yearID       1989
# teamID        DET
# lgID           AL
# salary    1310000
# Name: hernawi01, dtype: object, 'herndla01': yearID      1988
# teamID       DET
# lgID          AL
# salary    375000
# Name: herndla01, dtype: object, 'lapoida01': yearID      1990
# teamID       NYA
# lgID          AL
# salary    850000
# Name: lapoida01, dtype: object, 'lemonch01': yearID      1990
# teamID       DET
# lgID          AL
# salary    828571
# Name: lemonch01, dtype: object, 'lopezau01': yearID      1986
# teamID       HOU
# lgID          NL
# salary    223275
# Name: lopezau01, dtype: object, 'morrija02': yearID       1994
# teamID        TOR
# lgID           AL
# salary    1000000
# Name: morrija02, dtype: object, 'parrila02': yearID      1995
# teamID       TOR
# lgID          AL
# salary    290000
# Name: parrila02, dtype: object, 'petryda01': yearID      1991
# teamID       DET
# lgID          AL
# salary    650000
# Name: petryda01, dtype: object, 'scherbi01': yearID      1985
# teamID       DET
# lgID          AL
# salary    100000
# Name: scherbi01, dtype: object, 'terrewa01': yearID      1992
# teamID       DET
# lgID          AL
# salary    109000
# Name: terrewa01, dtype: object, 'trammal01': yearID      1996
# teamID       DET
# lgID          AL
# salary    600000
# Name: trammal01, dtype: object, 'whitalo01': yearID       1995
# teamID        DET
# lgID           AL
# salary    3783334
# Name: whitalo01, dtype: object, 'wilcomi01': yearID      1986
# teamID       SEA
# lgID          AL
# salary    150000
# Name: wilcomi01, dtype: object, 'ashbyal01': yearID      1988
# teamID       HOU
# lgID          NL
# salary    450000
# Name: ashbyal01, dtype: object, 'basske01': yearID      1995
# teamID       BAL
# lgID          AL
# salary    415000
# Name: basske01, dtype: object, 'cabelen01': yearID      1986
# teamID       LAN
# lgID          NL
# salary    450000
# Name: cabelen01, dtype: object, 'cruzjo01': yearID      1988
# teamID       NYA
# lgID          AL
# salary    350000
# Name: cruzjo01, dtype: object, 'davisgl01': yearID       1993
# teamID        BAL
# lgID           AL
# salary    3817500
# Name: davisgl01, dtype: object, 'dawlebi01': yearID      1987
# teamID       SLN
# lgID          NL
# salary    275000
# Name: dawlebi01, dtype: object, 'dipinfr01': yearID      1993
# teamID       KCA
# lgID          AL
# salary    350000
# Name: dipinfr01, dtype: object, 'doranbi02': yearID       1993
# teamID        ML4
# lgID           AL
# salary    1333334
# Name: doranbi02, dtype: object, 'garneph01': yearID      1988
# teamID       SFN
# lgID          NL
# salary    375000
# Name: garneph01, dtype: object, 'kneppbo01': yearID     1989
# teamID      HOU
# lgID         NL
# salary    68000
# Name: kneppbo01, dtype: object, 'morenom01': yearID      1987
# teamID       HOU
# lgID          NL
# salary    700000
# Name: morenom01, dtype: object, 'niekrjo01': yearID      1988
# teamID       MIN
# lgID          AL
# salary    800000
# Name: niekrjo01, dtype: object, 'puhlte01': yearID      1990
# teamID       HOU
# lgID          NL
# salary    800000
# Name: puhlte01, dtype: object, 'reynocr01': yearID      1989
# teamID       HOU
# lgID          NL
# salary    600000
# Name: reynocr01, dtype: object, 'ryanno01': yearID       1993
# teamID        TEX
# lgID           AL
# salary    3757000
# Name: ryanno01, dtype: object, 'scottmi03': yearID       1991
# teamID        HOU
# lgID           NL
# salary    2412500
# Name: scottmi03, dtype: object, 'smithda02': yearID      1993
# teamID       CHN
# lgID          NL
# salary    250000
# Name: smithda02, dtype: object, 'spilmha01': yearID      1989
# teamID       HOU
# lgID          NL
# salary    150000
# Name: spilmha01, dtype: object, 'thondi01': yearID      1993
# teamID       ML4
# lgID          AL
# salary    250000
# Name: thondi01, dtype: object, 'wallide01': yearID      1992
# teamID       HOU
# lgID          NL
# salary    300000
# Name: wallide01, dtype: object, 'balbost01': yearID      1990
# teamID       NYA
# lgID          AL
# salary    900000
# Name: balbost01, dtype: object, 'beckwjo01': yearID      1986
# teamID       LAN
# lgID          NL
# salary    200000
# Name: beckwjo01, dtype: object, 'blackbu02': yearID      1995
# teamID       CLE
# lgID          AL
# salary    350000
# Name: blackbu02, dtype: object, 'brettge01': yearID       1993
# teamID        KCA
# lgID           AL
# salary    2750000
# Name: brettge01, dtype: object, 'conceon01': yearID      1985
# teamID       KCA
# lgID          AL
# salary    250000
# Name: conceon01, dtype: object, 'gubicma01': yearID       1997
# teamID        ANA
# lgID           AL
# salary    1600000
# Name: gubicma01, dtype: object, 'jacksda02': yearID       1997
# teamID        SLN
# lgID           NL
# salary    4600000
# Name: jacksda02, dtype: object, 'jonesly01': yearID      1986
# teamID       KCA
# lgID          AL
# salary    185000
# Name: jonesly01, dtype: object, 'jonesmi02': yearID      1985
# teamID       KCA
# lgID          AL
# salary    100000
# Name: jonesmi02, dtype: object, 'lampde01': yearID      1991
# teamID       BOS
# lgID          AL
# salary    750000
# Name: lampde01, dtype: object, 'leibrch01': yearID       1993
# teamID        TEX
# lgID           AL
# salary    2833334
# Name: leibrch01, dtype: object, 'leonade01': yearID      1986
# teamID       KCA
# lgID          AL
# salary    883333
# Name: leonade01, dtype: object, 'mcraeha01': yearID      1986
# teamID       KCA
# lgID          AL
# salary    650000
# Name: mcraeha01, dtype: object, 'motleda01': yearID      1987
# teamID       ATL
# lgID          NL
# salary    210000
# Name: motleda01, dtype: object, 'ortajo01': yearID      1986
# teamID       KCA
# lgID          AL
# salary    450000
# Name: ortajo01, dtype: object, 'pryorgr01': yearID      1986
# teamID       KCA
# lgID          AL
# salary    293808
# Name: pryorgr01, dtype: object, 'quiseda01': yearID      1990
# teamID       SFN
# lgID          NL
# salary    100000
# Name: quiseda01, dtype: object, 'saberbr01': yearID       2001
# teamID        BOS
# lgID           AL
# salary    5000000
# Name: saberbr01, dtype: object, 'sheripa01': yearID      1989
# teamID       DET
# lgID          AL
# salary    430000
# Name: sheripa01, dtype: object, 'sundbji01': yearID      1989
# teamID       TEX
# lgID          AL
# salary    475000
# Name: sundbji01, dtype: object, 'wathajo01': yearID      1986
# teamID       KCA
# lgID          AL
# salary    400000
# Name: wathajo01, dtype: object, 'wilsowi02': yearID      1994
# teamID       CHN
# lgID          NL
# salary    700000
# Name: wilsowi02, dtype: object, 'bailobo01': yearID      1986
# teamID       LAN
# lgID          NL
# salary    375000
# Name: bailobo01, dtype: object, 'brockgr01': yearID      1991
# teamID       ML4
# lgID          AL
# salary    937500
# Name: brockgr01, dtype: object, 'diazca01': yearID      1985
# teamID       LAN
# lgID          NL
# salary    120000
# Name: diazca01, dtype: object, 'duncama01': yearID      1997
# teamID       NYA
# lgID          AL
# salary    870000
# Name: duncama01, dtype: object, 'goltzda01': yearID      1985
# teamID       LAN
# lgID          NL
# salary    500000
# Name: goltzda01, dtype: object, 'guerrpe01': yearID       1992
# teamID        SLN
# lgID           NL
# salary    2425000
# Name: guerrpe01, dtype: object, 'hershor01': yearID       2000
# teamID        LAN
# lgID           NL
# salary    2000000
# Name: hershor01, dtype: object, 'honeyri01': yearID      1997
# teamID       SLN
# lgID          NL
# salary    500000
# Name: honeyri01, dtype: object, 'johnsja01': yearID      1985
# teamID       LAN
# lgID          NL
# salary    150000
# Name: johnsja01, dtype: object, 'landrke01': yearID      1987
# teamID       LAN
# lgID          NL
# salary    737500
# Name: landrke01, dtype: object, 'maldoca01': yearID      1995
# teamID       TOR
# lgID          AL
# salary    200000
# Name: maldoca01, dtype: object, 'marshmi02': yearID       1991
# teamID        BOS
# lgID           AL
# salary    1300000
# Name: marshmi02, dtype: object, 'niedeto01': yearID      1990
# teamID       SEA
# lgID          AL
# salary    800000
# Name: niedeto01, dtype: object, 'oliveal01': yearID      1985
# teamID       LAN
# lgID          NL
# salary    750000
# Name: oliveal01, dtype: object, 'penaal01': yearID     1997
# teamID      FLO
# lgID         NL
# salary    50000
# Name: penaal01, dtype: object, 'reussje01': yearID      1989
# teamID       CHA
# lgID          AL
# salary    590000
# Name: reussje01, dtype: object, 'russebi01': yearID      1986
# teamID       LAN
# lgID          NL
# salary    450000
# Name: russebi01, dtype: object, 'saxst01': yearID       1995
# teamID        CHA
# lgID           AL
# salary    3475000
# Name: saxst01, dtype: object, 'sciosmi01': yearID      1993
# teamID       SDN
# lgID          NL
# salary    300000
# Name: sciosmi01, dtype: object, 'valenfe01': yearID       1997
# teamID        SDN
# lgID           NL
# salary    1650000
# Name: valenfe01, dtype: object, 'welchbo01': yearID       1994
# teamID        OAK
# lgID           AL
# salary    3450000
# Name: welchbo01, dtype: object, 'whitfte01': yearID      1985
# teamID       LAN
# lgID          NL
# salary    316667
# Name: whitfte01, dtype: object, 'yeagest01': yearID      1986
# teamID       SEA
# lgID          AL
# salary    412809
# Name: yeagest01, dtype: object, 'anderal02': yearID      1991
# teamID       MIN
# lgID          AL
# salary    785000
# Name: anderal02, dtype: object, 'brunato01': yearID       1994
# teamID        ML4
# lgID           AL
# salary    1100000
# Name: brunato01, dtype: object, 'bushra01': yearID      1993
# teamID       MIN
# lgID          AL
# salary    250000
# Name: bushra01, dtype: object, 'butchjo01': yearID      1986
# teamID       MIN
# lgID          AL
# salary    385000
# Name: butchjo01, dtype: object, 'castijo01': yearID      1985
# teamID       MIN
# lgID          AL
# salary    550000
# Name: castijo01, dtype: object, 'davisro02': yearID      1986
# teamID       MIN
# lgID          AL
# salary    725000
# Name: davisro02, dtype: object, 'engleda01': yearID      1988
# teamID       MON
# lgID          NL
# salary    150000
# Name: engleda01, dtype: object, 'filsope01': yearID      1987
# teamID       NYA
# lgID          AL
# salary    180000
# Name: filsope01, dtype: object, 'gaettga01': yearID      2000
# teamID       BOS
# lgID          AL
# salary    350000
# Name: gaettga01, dtype: object, 'hatchmi01': yearID      1990
# teamID       LAN
# lgID          NL
# salary    450000
# Name: hatchmi01, dtype: object, 'hrbekke01': yearID       1994
# teamID        MIN
# lgID           AL
# salary    3100000
# Name: hrbekke01, dtype: object, 'laudnti01': yearID      1990
# teamID       MIN
# lgID          AL
# salary    625000
# Name: laudnti01, dtype: object, 'puckeki01': yearID       1997
# teamID        MIN
# lgID           AL
# salary    7200000
# Name: puckeki01, dtype: object, 'salasma01': yearID      1991
# teamID       DET
# lgID          AL
# salary    450000
# Name: salasma01, dtype: object, 'schroke01': yearID      1987
# teamID       CLE
# lgID          AL
# salary    450000
# Name: schroke01, dtype: object, 'smallro02': yearID      1986
# teamID       MIN
# lgID          AL
# salary    740000
# Name: smallro02, dtype: object, 'smithmi03': yearID      1990
# teamID       CAL
# lgID          AL
# salary    480000
# Name: smithmi03, dtype: object, 'teufeti01': yearID      1993
# teamID       SDN
# lgID          NL
# salary    762500
# Name: teufeti01, dtype: object, 'violafr01': yearID      1995
# teamID       CIN
# lgID          NL
# salary    190000
# Name: violafr01, dtype: object, 'burrira01': yearID      1987
# teamID       ML4
# lgID          AL
# salary    100000
# Name: burrira01, dtype: object, 'coopece01': yearID      1987
# teamID       ML4
# lgID          AL
# salary    493224
# Name: coopece01, dtype: object, 'darwida01': yearID      1998
# teamID       SFN
# lgID          NL
# salary    710000
# Name: darwida01, dtype: object, 'fingero01': yearID       1985
# teamID        ML4
# lgID           AL
# salary    1065000
# Name: fingero01, dtype: object, 'gantnji01': yearID       1992
# teamID        ML4
# lgID           AL
# salary    1150000
# Name: gantnji01, dtype: object, 'haasmo01': yearID      1987
# teamID       OAK
# lgID          AL
# salary    578889
# Name: haasmo01, dtype: object, 'higuete01': yearID       1994
# teamID        ML4
# lgID           AL
# salary    3500000
# Name: higuete01, dtype: object, 'housepa02': yearID      1985
# teamID       ML4
# lgID          AL
# salary    215000
# Name: housepa02, dtype: object, 'manniri01': yearID      1987
# teamID       ML4
# lgID          AL
# salary    560000
# Name: manniri01, dtype: object, 'mcclubo01': yearID      1993
# teamID       FLO
# lgID          NL
# salary    200000
# Name: mcclubo01, dtype: object, 'molitpa01': yearID       1998
# teamID        MIN
# lgID           AL
# salary    4250000
# Name: molitpa01, dtype: object, 'moorech02': yearID      1987
# teamID       TOR
# lgID          AL
# salary    256000
# Name: moorech02, dtype: object, 'oglivbe01': yearID      1986
# teamID       ML4
# lgID          AL
# salary    766593
# Name: oglivbe01, dtype: object, 'romered01': yearID      1990
# teamID       DET
# lgID          AL
# salary    350000
# Name: romered01, dtype: object, 'schrobi01': yearID      1990
# teamID       CAL
# lgID          AL
# salary    407500
# Name: schrobi01, dtype: object, 'simmote01': yearID      1988
# teamID       ATL
# lgID          NL
# salary    470000
# Name: simmote01, dtype: object, 'vuckope01': yearID      1985
# teamID       ML4
# lgID          AL
# salary    540000
# Name: vuckope01, dtype: object, 'waitsri01': yearID      1985
# teamID       ML4
# lgID          AL
# salary    460000
# Name: waitsri01, dtype: object, 'yountro01': yearID       1993
# teamID        ML4
# lgID           AL
# salary    2700000
# Name: yountro01, dtype: object, 'brookhu01': yearID      1994
# teamID       KCA
# lgID          AL
# salary    350000
# Name: brookhu01, dtype: object, 'dawsoan01': yearID      1996
# teamID       FLO
# lgID          NL
# salary    500000
# Name: dawsoan01, dtype: object, 'dilonmi01': yearID      1985
# teamID       MON
# lgID          NL
# salary    175000
# Name: dilonmi01, dtype: object, 'fishebr01': yearID      1989
# teamID       PIT
# lgID          NL
# salary    404000
# Name: fishebr01, dtype: object, 'flynndo01': yearID      1986
# teamID       MON
# lgID          NL
# salary    325000
# Name: flynndo01, dtype: object, 'francte01': yearID      1990
# teamID       ML4
# lgID          AL
# salary    150000
# Name: francte01, dtype: object, 'gullibi01': yearID       1994
# teamID        DET
# lgID           AL
# salary    2400000
# Name: gullibi01, dtype: object, 'lawva01': yearID      1991
# teamID       OAK
# lgID          AL
# salary    500000
# Name: lawva01, dtype: object, 'leach01': yearID     1988
# teamID      MIN
# lgID         AL
# salary    62500
# Name: leach01, dtype: object, 'lucasga01': yearID      1987
# teamID       CAL
# lgID          AL
# salary    662000
# Name: lucasga01, dtype: object, 'nicosst01': yearID      1985
# teamID       MON
# lgID          NL
# salary    105000
# Name: nicosst01, dtype: object, 'palmeda01': yearID      1988
# teamID       PHI
# lgID          NL
# salary    675000
# Name: palmeda01, dtype: object, 'raineti01': yearID      2002
# teamID       FLO
# lgID          NL
# salary    350000
# Name: raineti01, dtype: object, 'reardje01': yearID      1994
# teamID       NYA
# lgID          AL
# salary    250000
# Name: reardje01, dtype: object, 'roberbe01': yearID      1986
# teamID       MON
# lgID          NL
# salary    138100
# Name: roberbe01, dtype: object, 'schatda01': yearID      1991
# teamID       KCA
# lgID          AL
# salary    700000
# Name: schatda01, dtype: object, 'smithbr01': yearID      1993
# teamID       COL
# lgID          NL
# salary    250000
# Name: smithbr01, dtype: object, 'wallati01': yearID      1996
# teamID       LAN
# lgID          NL
# salary    109000
# Name: wallati01, dtype: object, 'washiul01': yearID     1987
# teamID      PIT
# lgID         NL
# salary    80000
# Name: washiul01, dtype: object, 'wohlfji01': yearID      1986
# teamID       MON
# lgID          NL
# salary    350000
# Name: wohlfji01, dtype: object, 'baylodo01': yearID      1988
# teamID       OAK
# lgID          AL
# salary    495000
# Name: baylodo01, dtype: object, 'berrada01': yearID      1987
# teamID       NYA
# lgID          AL
# salary    657500
# Name: berrada01, dtype: object, 'bystrma01': yearID      1985
# teamID       NYA
# lgID          AL
# salary    250000
# Name: bystrma01, dtype: object, 'cowlejo01': yearID      1986
# teamID       CHA
# lgID          AL
# salary    295000
# Name: cowlejo01, dtype: object, 'griffke01': yearID      1990
# teamID       CIN
# lgID          NL
# salary    510000
# Name: griffke01, dtype: object, 'guidrro01': yearID      1988
# teamID       NYA
# lgID          AL
# salary    825000
# Name: guidrro01, dtype: object, 'hassero01': yearID      1990
# teamID       OAK
# lgID          AL
# salary    700000
# Name: hassero01, dtype: object, 'henderi01': yearID      2002
# teamID       BOS
# lgID          AL
# salary    350000
# Name: henderi01, dtype: object, 'kempst01': yearID       1987
# teamID        NYA
# lgID           AL
# salary    1320000
# Name: kempst01, dtype: object, 'mattido01': yearID       1995
# teamID        NYA
# lgID           AL
# salary    4420000
# Name: mattido01, dtype: object, 'meachbo01': yearID      1988
# teamID       NYA
# lgID          AL
# salary    212500
# Name: meachbo01, dtype: object, 'montejo01': yearID      1986
# teamID       NYA
# lgID          AL
# salary    716667
# Name: montejo01, dtype: object, 'niekrph01': yearID      1986
# teamID       CLE
# lgID          AL
# salary    300000
# Name: niekrph01, dtype: object, 'randowi01': yearID      1992
# teamID       NYN
# lgID          NL
# salary    850000
# Name: randowi01, dtype: object, 'righeda01': yearID      1995
# teamID       CHA
# lgID          AL
# salary    300000
# Name: righeda01, dtype: object, 'samplbi01': yearID      1986
# teamID       ATL
# lgID          NL
# salary    470000
# Name: samplbi01, dtype: object, 'shirlbo01': yearID      1986
# teamID       NYA
# lgID          AL
# salary    750000
# Name: shirlbo01, dtype: object, 'whitsed01': yearID       1991
# teamID        SDN
# lgID           NL
# salary    1325000
# Name: whitsed01, dtype: object, 'winfida01': yearID      1995
# teamID       CLE
# lgID          AL
# salary    600000
# Name: winfida01, dtype: object, 'wynegbu01': yearID      1988
# teamID       CAL
# lgID          AL
# salary    733333
# Name: wynegbu01, dtype: object, 'backmwa01': yearID      1992
# teamID       PHI
# lgID          NL
# salary    650000
# Name: backmwa01, dtype: object, 'berenbr01': yearID      1985
# teamID       NYN
# lgID          NL
# salary    325000
# Name: berenbr01, dtype: object, 'bowala01': yearID      1985
# teamID       NYN
# lgID          NL
# salary    525000
# Name: bowala01, dtype: object, 'cartega01': yearID      1992
# teamID       MON
# lgID          NL
# salary    825000
# Name: cartega01, dtype: object, 'darliro01': yearID       1995
# teamID        OAK
# lgID           AL
# salary    3000000
# Name: darliro01, dtype: object, 'fostege01': yearID       1986
# teamID        NYN
# lgID           NL
# salary    2800000
# Name: fostege01, dtype: object, 'gardero01': yearID      1985
# teamID       NYN
# lgID          NL
# salary    100000
# Name: gardero01, dtype: object, 'goodedw01': yearID      2000
# teamID       HOU
# lgID          NL
# salary    500000
# Name: goodedw01, dtype: object, 'gormato03': yearID      1985
# teamID       NYN
# lgID          NL
# salary    150000
# Name: gormato03, dtype: object, 'heepda01': yearID      1990
# teamID       BOS
# lgID          AL
# salary    595000
# Name: heepda01, dtype: object, 'hernake01': yearID       1991
# teamID        CLE
# lgID           AL
# salary    1750000
# Name: hernake01, dtype: object, 'johnsho01': yearID      1995
# teamID       COL
# lgID          NL
# salary    400000
# Name: johnsho01, dtype: object, 'knighra01': yearID      1988
# teamID       DET
# lgID          AL
# salary    525000
# Name: knighra01, dtype: object, 'lynched01': yearID      1987
# teamID       CHN
# lgID          NL
# salary    550000
# Name: lynched01, dtype: object, 'mcdowro01': yearID      1996
# teamID       BAL
# lgID          AL
# salary    750000
# Name: mcdowro01, dtype: object, 'oroscje01': yearID      2003
# teamID       SDN
# lgID          NL
# salary    800000
# Name: oroscje01, dtype: object, 'santara01': yearID      1990
# teamID       CLE
# lgID          AL
# salary    250000
# Name: santara01, dtype: object, 'siskdo01': yearID      1988
# teamID       BAL
# lgID          AL
# salary    410000
# Name: siskdo01, dtype: object, 'staubru01': yearID      1985
# teamID       NYN
# lgID          NL
# salary    300000
# Name: staubru01, dtype: object, 'strawda01': yearID      1998
# teamID       NYA
# lgID          AL
# salary    875000
# Name: strawda01, dtype: object, 'wilsomo01': yearID       1991
# teamID        TOR
# lgID           AL
# salary    1625000
# Name: wilsomo01, dtype: object, 'atherke01': yearID      1988
# teamID       MIN
# lgID          AL
# salary    345000
# Name: atherke01, dtype: object, 'bakerdu01': yearID      1986
# teamID       OAK
# lgID          AL
# salary    475000
# Name: bakerdu01, dtype: object, 'birtsti01': yearID      1990
# teamID       CIN
# lgID          NL
# salary    120500
# Name: birtsti01, dtype: object, 'bochtbr01': yearID      1986
# teamID       OAK
# lgID          AL
# salary    572500
# Name: bochtbr01, dtype: object, 'codirch01': yearID      1986
# teamID       OAK
# lgID          AL
# salary    270000
# Name: codirch01, dtype: object, 'collida02': yearID      1989
# teamID       CIN
# lgID          NL
# salary    225000
# Name: collida02, dtype: object, 'davismi02': yearID      1989
# teamID       LAN
# lgID          NL
# salary    987500
# Name: davismi02, dtype: object, 'griffal01': yearID      1993
# teamID       TOR
# lgID          AL
# salary    500000
# Name: griffal01, dtype: object, 'heathmi02': yearID      1991
# teamID       ATL
# lgID          NL
# salary    950000
# Name: heathmi02, dtype: object, 'hendest01': yearID     1987
# teamID      OAK
# lgID         AL
# salary    75000
# Name: hendest01, dtype: object, 'howelja01': yearID      1994
# teamID       TEX
# lgID          AL
# salary    805000
# Name: howelja01, dtype: object, 'johnto01': yearID      1988
# teamID       NYA
# lgID          AL
# salary    375000
# Name: johnto01, dtype: object, 'kingmda01': yearID      1986
# teamID       OAK
# lgID          AL
# salary    730000
# Name: kingmda01, dtype: object, 'langfri01': yearID      1986
# teamID       OAK
# lgID          AL
# salary    500000
# Name: langfri01, dtype: object, 'lansfca01': yearID       1992
# teamID        OAK
# lgID           AL
# salary    1150000
# Name: lansfca01, dtype: object, 'mccatst01': yearID      1985
# teamID       OAK
# lgID          AL
# salary    520000
# Name: mccatst01, dtype: object, 'murphdw01': yearID      1989
# teamID       PHI
# lgID          NL
# salary    400000
# Name: murphdw01, dtype: object, 'norrimi01': yearID      1990
# teamID       OAK
# lgID          AL
# salary    100000
# Name: norrimi01, dtype: object, 'phillto02': yearID      1999
# teamID       OAK
# lgID          AL
# salary    700000
# Name: phillto02, dtype: object, 'picciro01': yearID      1985
# teamID       OAK
# lgID          AL
# salary    100000
# Name: picciro01, dtype: object, 'tellmto01': yearID      1985
# teamID       OAK
# lgID          AL
# salary    207500
# Name: tellmto01, dtype: object, 'aguaylu01': yearID      1989
# teamID       CLE
# lgID          AL
# salary    275000
# Name: aguaylu01, dtype: object, 'anderla02': yearID      1994
# teamID       PHI
# lgID          NL
# salary    350000
# Name: anderla02, dtype: object, 'carltst01': yearID      1988
# teamID       MIN
# lgID          AL
# salary    115000
# Name: carltst01, dtype: object, 'corcoti01': yearID      1986
# teamID       NYN
# lgID          NL
# salary    220000
# Name: corcoti01, dtype: object, 'dennyjo01': yearID       1986
# teamID        CIN
# lgID           NL
# salary    1083333
# Name: dennyjo01, dtype: object, 'diazbo01': yearID      1989
# teamID       CIN
# lgID          NL
# salary    900000
# Name: diazbo01, dtype: object, 'grossgr01': yearID      1988
# teamID       PHI
# lgID          NL
# salary    320000
# Name: grossgr01, dtype: object, 'grosske01': yearID       1996
# teamID        TEX
# lgID           AL
# salary    3300000
# Name: grosske01, dtype: object, 'hayesvo01': yearID       1992
# teamID        CAL
# lgID           AL
# salary    2200000
# Name: hayesvo01, dtype: object, 'hudsoch02': yearID      1989
# teamID       DET
# lgID          AL
# salary    525000
# Name: hudsoch02, dtype: object, 'kniceal01': yearID     1986
# teamID      PHI
# lgID         NL
# salary    80000
# Name: kniceal01, dtype: object, 'koosmje01': yearID      1985
# teamID       PHI
# lgID          NL
# salary    600000
# Name: koosmje01, dtype: object, 'lefebjo01': yearID      1985
# teamID       PHI
# lgID          NL
# salary    310000
# Name: lefebjo01, dtype: object, 'maddoga01': yearID      1985
# teamID       PHI
# lgID          NL
# salary    820333
# Name: maddoga01, dtype: object, 'rawlesh01': yearID      1990
# teamID       BOS
# lgID          AL
# salary    350000
# Name: rawlesh01, dtype: object, 'ruckeda01': yearID      1985
# teamID       PHI
# lgID          NL
# salary    220000
# Name: ruckeda01, dtype: object, 'samueju01': yearID      1998
# teamID       TOR
# lgID          AL
# salary    421000
# Name: samueju01, dtype: object, 'schmimi01': yearID       1988
# teamID        PHI
# lgID           NL
# salary    2250000
# Name: schmimi01, dtype: object, 'virgioz02': yearID      1990
# teamID       TOR
# lgID          AL
# salary    275000
# Name: virgioz02, dtype: object, 'almonbi01': yearID      1988
# teamID       PHI
# lgID          NL
# salary    250000
# Name: almonbi01, dtype: object, 'deleojo01': yearID      1995
# teamID       CHA
# lgID          AL
# salary    705000
# Name: deleojo01, dtype: object, 'guantce01': yearID      1990
# teamID       CLE
# lgID          AL
# salary    650000
# Name: guantce01, dtype: object, 'hasslan01': yearID      1985
# teamID       PIT
# lgID          NL
# salary    129166
# Name: hasslan01, dtype: object, 'lezcasi01': yearID      1986
# teamID       PIT
# lgID          NL
# salary    500000
# Name: lezcasi01, dtype: object, 'madlobi01': yearID      1987
# teamID       LAN
# lgID          NL
# salary    850000
# Name: madlobi01, dtype: object, 'mazzile01': yearID      1989
# teamID       NYN
# lgID          NL
# salary    350000
# Name: mazzile01, dtype: object, 'mcwilla01': yearID      1990
# teamID       KCA
# lgID          AL
# salary    300000
# Name: mcwilla01, dtype: object, 'morriji01': yearID      1988
# teamID       DET
# lgID          AL
# salary    277500
# Name: morriji01, dtype: object, 'orsuljo01': yearID      1997
# teamID       MON
# lgID          NL
# salary    650000
# Name: orsuljo01, dtype: object, 'penato01': yearID      1997
# teamID       CHA
# lgID          AL
# salary    425000
# Name: penato01, dtype: object, 'rayjo01': yearID       1990
# teamID        CAL
# lgID           AL
# salary    1125000
# Name: rayjo01, dtype: object, 'reuscri01': yearID       1991
# teamID        SFN
# lgID           NL
# salary    1350000
# Name: reuscri01, dtype: object, 'rhoderi01': yearID      1989
# teamID       HOU
# lgID          NL
# salary    900000
# Name: rhoderi01, dtype: object, 'robindo01': yearID      1992
# teamID       CAL
# lgID          AL
# salary    900000
# Name: robindo01, dtype: object, 'scurrro01': yearID      1987
# teamID       NYA
# lgID          AL
# salary    340000
# Name: scurrro01, dtype: object, 'tekulke01': yearID      1988
# teamID       PHI
# lgID          NL
# salary    850000
# Name: tekulke01, dtype: object, 'thompja01': yearID       1987
# teamID        PIT
# lgID           NL
# salary    1150000
# Name: thompja01, dtype: object, 'tunnele01': yearID     1987
# ...
# salary    504300
# Name: jordata01, dtype: object, 'koberje01': yearID      2014
# teamID       WAS
# lgID          NL
# salary    501000
# Name: koberje01, dtype: object, 'leonsa01': yearID      2015
# teamID       BOS
# lgID          AL
# salary    510400
# Name: leonsa01, dtype: object, 'rendoan01': yearID       2015
# teamID        WAS
# lgID           NL
# salary    2500000
# Name: rendoan01, dtype: object, 'roarkta01': yearID      2015
# teamID       WAS
# lgID          NL
# salary    529600
# Name: roarkta01, dtype: object, 'ahmedni01': yearID      2015
# teamID       ARI
# lgID          NL
# salary    508500
# Name: ahmedni01, dtype: object, 'anderch01': yearID      2015
# teamID       ARI
# lgID          NL
# salary    512500
# Name: anderch01, dtype: object, 'chafian01': yearID      2015
# teamID       ARI
# lgID          NL
# salary    507500
# Name: chafian01, dtype: object, 'inciaen01': yearID      2015
# teamID       ARI
# lgID          NL
# salary    513000
# Name: inciaen01, dtype: object, 'lambja01': yearID      2015
# teamID       ARI
# lgID          NL
# salary    508500
# Name: lambja01, dtype: object, 'marshev01': yearID      2015
# teamID       ARI
# lgID          NL
# salary    512000
# Name: marshev01, dtype: object, 'peralda01': yearID       2015
# teamID        ARI
# lgID           NL
# salary    1024000
# Name: peralda01, dtype: object, 'stitema01': yearID      2015
# teamID       ARI
# lgID          NL
# salary    510500
# Name: stitema01, dtype: object, 'tomasya01': yearID       2015
# teamID        ARI
# lgID           NL
# salary    5500000
# Name: tomasya01, dtype: object, 'bethach01': yearID      2015
# teamID       ATL
# lgID          NL
# salary    507500
# Name: bethach01, dtype: object, 'cunnito01': yearID      2015
# teamID       ATL
# lgID          NL
# salary    507500
# Name: cunnito01, dtype: object, 'foltymi01': yearID      2015
# teamID       ATL
# lgID          NL
# salary    508750
# Name: foltymi01, dtype: object, 'gosseph01': yearID      2015
# teamID       ATL
# lgID          NL
# salary    507500
# Name: gosseph01, dtype: object, 'peterja01': yearID      2015
# teamID       ATL
# lgID          NL
# salary    507500
# Name: peterja01, dtype: object, 'terdojo01': yearID      2015
# teamID       ATL
# lgID          NL
# salary    507500
# Name: terdojo01, dtype: object, 'josepca01': yearID      2015
# teamID       BAL
# lgID          AL
# salary    515000
# Name: josepca01, dtype: object, 'paredji01': yearID      2015
# teamID       BAL
# lgID          AL
# salary    515000
# Name: paredji01, dtype: object, 'barnema01': yearID      2015
# teamID       BOS
# lgID          AL
# salary    508500
# Name: barnema01, dtype: object, 'bettsmo01': yearID      2015
# teamID       BOS
# lgID          AL
# salary    514500
# Name: bettsmo01, dtype: object, 'cecchga01': yearID      2015
# teamID       BOS
# lgID          AL
# salary    508500
# Name: cecchga01, dtype: object, 'hembrhe01': yearID      2015
# teamID       BOS
# lgID          AL
# salary    509500
# Name: hembrhe01, dtype: object, 'holtbr01': yearID      2015
# teamID       BOS
# lgID          AL
# salary    530500
# Name: holtbr01, dtype: object, 'petrija01': yearID      2015
# teamID       CHA
# lgID          AL
# salary    520000
# Name: petrija01, dtype: object, 'putnaza01': yearID      2015
# teamID       CHA
# lgID          AL
# salary    525000
# Name: putnaza01, dtype: object, 'sanchca01': yearID      2015
# teamID       CHA
# lgID          AL
# salary    510000
# Name: sanchca01, dtype: object, 'alcanar01': yearID      2015
# teamID       CHN
# lgID          NL
# salary    510000
# Name: alcanar01, dtype: object, 'beeleda01': yearID      2015
# teamID       CHN
# lgID          NL
# salary    508000
# Name: beeleda01, dtype: object, 'hendrky01': yearID      2015
# teamID       CHN
# lgID          NL
# salary    510000
# Name: hendrky01, dtype: object, 'lasteto01': yearID      2015
# teamID       CHN
# lgID          NL
# salary    513000
# Name: lasteto01, dtype: object, 'ramirne01': yearID      2015
# teamID       CHN
# lgID          NL
# salary    514500
# Name: ramirne01, dtype: object, 'solerjo01': yearID       2015
# teamID        CHN
# lgID           NL
# salary    2666667
# Name: solerjo01, dtype: object, 'szczuma01': yearID      2015
# teamID       CHN
# lgID          NL
# salary    508500
# Name: szczuma01, dtype: object, 'wadats01': yearID       2015
# teamID        CHN
# lgID           NL
# salary    4000000
# Name: wadats01, dtype: object, 'desclan01': yearID      2015
# teamID       CIN
# lgID          NL
# salary    507500
# Name: desclan01, dtype: object, 'diazju03': yearID      2015
# teamID       CIN
# lgID          NL
# salary    510000
# Name: diazju03, dtype: object, 'iglesra01': yearID       2015
# teamID        CIN
# lgID           NL
# salary    1714286
# Name: iglesra01, dtype: object, 'negrokr01': yearID      2015
# teamID       CIN
# lgID          NL
# salary    512500
# Name: negrokr01, dtype: object, 'adamsau01': yearID      2015
# teamID       CLE
# lgID          AL
# salary    507700
# Name: adamsau01, dtype: object, 'crockky01': yearID      2015
# teamID       CLE
# lgID          AL
# salary    510900
# Name: crockky01, dtype: object, 'housetj01': yearID      2015
# teamID       CLE
# lgID          AL
# salary    511900
# Name: housetj01, dtype: object, 'perezro02': yearID      2015
# teamID       CLE
# lgID          AL
# salary    508600
# Name: perezro02, dtype: object, 'ramirjo01': yearID      2015
# teamID       CLE
# lgID          AL
# salary    511300
# Name: ramirjo01, dtype: object, 'walteza01': yearID      2015
# teamID       CLE
# lgID          AL
# salary    509600
# Name: walteza01, dtype: object, 'brownbr02': yearID      2015
# teamID       COL
# lgID          NL
# salary    509500
# Name: brownbr02, dtype: object, 'butleed01': yearID      2015
# teamID       COL
# lgID          NL
# salary    509500
# Name: butleed01, dtype: object, 'friedch01': yearID      2015
# teamID       COL
# lgID          NL
# salary    512500
# Name: friedch01, dtype: object, 'matzety01': yearID      2015
# teamID       COL
# lgID          NL
# salary    509500
# Name: matzety01, dtype: object, 'gosean01': yearID      2015
# teamID       DET
# lgID          AL
# salary    515000
# Name: gosean01, dtype: object, 'greensh02': yearID      2015
# teamID       DET
# lgID          AL
# salary    515000
# Name: greensh02, dtype: object, 'mccanja02': yearID      2015
# teamID       DET
# lgID          AL
# salary    507500
# Name: mccanja02, dtype: object, 'perezhe01': yearID      2015
# teamID       DET
# lgID          AL
# salary    508500
# Name: perezhe01, dtype: object, 'rondobr01': yearID      2015
# teamID       DET
# lgID          AL
# salary    510000
# Name: rondobr01, dtype: object, 'mchugco01': yearID      2015
# teamID       HOU
# lgID          AL
# salary    516300
# Name: mchugco01, dtype: object, 'oberhbr01': yearID      2015
# teamID       HOU
# lgID          AL
# salary    515800
# Name: oberhbr01, dtype: object, 'springe01': yearID      2015
# teamID       HOU
# lgID          AL
# salary    512900
# Name: springe01, dtype: object, 'colonch01': yearID      2015
# teamID       KCA
# lgID          AL
# salary    509525
# Name: colonch01, dtype: object, 'alvarjo02': yearID      2015
# teamID       LAA
# lgID          AL
# salary    509500
# Name: alvarjo02, dtype: object, 'croncj01': yearID      2015
# teamID       LAA
# lgID          AL
# salary    512500
# Name: croncj01, dtype: object, 'morinmi01': yearID      2015
# teamID       LAA
# lgID          AL
# salary    514000
# Name: morinmi01, dtype: object, 'navaref01': yearID      2015
# teamID       LAA
# lgID          AL
# salary    511000
# Name: navaref01, dtype: object, 'roberda09': yearID      2015
# teamID       LAA
# lgID          AL
# salary    511250
# Name: roberda09, dtype: object, 'baezpe01': yearID      2015
# teamID       LAN
# lgID          NL
# salary    512500
# Name: baezpe01, dtype: object, 'garciyi01': yearID      2015
# teamID       LAN
# lgID          NL
# salary    510000
# Name: garciyi01, dtype: object, 'hatchch02': yearID      2015
# teamID       LAN
# lgID          NL
# salary    522500
# Name: hatchch02, dtype: object, 'pederjo01': yearID      2015
# teamID       LAN
# lgID          NL
# salary    510000
# Name: pederjo01, dtype: object, 'dysonsa01': yearID      2015
# teamID       MIA
# lgID          NL
# salary    507500
# Name: dysonsa01, dtype: object, 'blazemi01': yearID      2015
# teamID       MIL
# lgID          NL
# salary    508500
# Name: blazemi01, dtype: object, 'centeju01': yearID      2015
# teamID       MIL
# lgID          NL
# salary    507500
# Name: centeju01, dtype: object, 'nelsoji02': yearID      2015
# teamID       MIL
# lgID          NL
# salary    511500
# Name: nelsoji02, dtype: object, 'rogerja02': yearID      2015
# teamID       MIL
# lgID          NL
# salary    507500
# Name: rogerja02, dtype: object, 'santada01': yearID      2015
# teamID       MIN
# lgID          AL
# salary    530000
# Name: santada01, dtype: object, 'thompaa01': yearID      2015
# teamID       MIN
# lgID          AL
# salary    520000
# Name: thompaa01, dtype: object, 'vargake01': yearID      2015
# teamID       MIN
# lgID          AL
# salary    517500
# Name: vargake01, dtype: object, 'martich02': yearID      2015
# teamID       NYA
# lgID          AL
# salary    511025
# Name: martich02, dtype: object, 'petitgr01': yearID      2015
# teamID       NYA
# lgID          AL
# salary    510000
# Name: petitgr01, dtype: object, 'pireljo01': yearID      2015
# teamID       NYA
# lgID          AL
# salary    510000
# Name: pireljo01, dtype: object, 'shrevch01': yearID      2015
# teamID       NYA
# lgID          AL
# salary    510275
# Name: shrevch01, dtype: object, 'campber01': yearID      2015
# teamID       NYN
# lgID          NL
# salary    511065
# Name: campber01, dtype: object, 'degroja01': yearID      2015
# teamID       NYN
# lgID          NL
# salary    556875
# Name: degroja01, dtype: object, 'florewi01': yearID      2015
# teamID       NYN
# lgID          NL
# salary    513543
# Name: florewi01, dtype: object, 'goedder01': yearID      2015
# teamID       NYN
# lgID          NL
# salary    509125
# Name: goedder01, dtype: object, 'montera01': yearID      2015
# teamID       NYN
# lgID          NL
# salary    511000
# Name: montera01, dtype: object, 'alvarrj01': yearID      2015
# teamID       OAK
# lgID          AL
# salary    507500
# Name: alvarrj01, dtype: object, 'graveke01': yearID      2015
# teamID       OAK
# lgID          AL
# salary    507500
# Name: graveke01, dtype: object, 'hahnje01': yearID      2015
# teamID       OAK
# lgID          AL
# salary    507500
# Name: hahnje01, dtype: object, 'phegljo01': yearID      2015
# teamID       OAK
# lgID          AL
# salary    510000
# Name: phegljo01, dtype: object, 'pomerdr01': yearID      2015
# teamID       OAK
# lgID          AL
# salary    517500
# Name: pomerdr01, dtype: object, 'buchada01': yearID      2015
# teamID       PHI
# lgID          NL
# salary    512500
# Name: buchada01, dtype: object, 'garcilu03': yearID      2015
# teamID       PHI
# lgID          NL
# salary    509000
# Name: garcilu03, dtype: object, 'gileske01': yearID      2015
# teamID       PHI
# lgID          NL
# salary    519000
# Name: gileske01, dtype: object, 'caminar01': yearID      2015
# teamID       PIT
# lgID          NL
# salary    515500
# Name: caminar01, dtype: object, 'deckeja01': yearID      2015
# teamID       PIT
# lgID          NL
# salary    510000
# Name: deckeja01, dtype: object, 'kangju01': yearID       2015
# teamID        PIT
# lgID           NL
# salary    2500000
# Name: kangju01, dtype: object, 'lamboan01': yearID      2015
# teamID       PIT
# lgID          NL
# salary    515500
# Name: lamboan01, dtype: object, 'lizra01': yearID       2015
# teamID        PIT
# lgID           NL
# salary    1000000
# Name: lizra01, dtype: object, 'polangr01': yearID      2015
# teamID       PIT
# lgID          NL
# salary    525000
# Name: polangr01, dtype: object, 'despaod01': yearID      2015
# teamID       SDN
# lgID          NL
# salary    517300
# Name: despaod01, dtype: object, 'garcefr01': yearID      2015
# teamID       SDN
# lgID          NL
# salary    508500
# Name: garcefr01, dtype: object, 'solarya01': yearID      2015
# teamID       SDN
# lgID          NL
# salary    516400
# Name: solarya01, dtype: object, 'spangco01': yearID      2015
# teamID       SDN
# lgID          NL
# salary    508500
# Name: spangco01, dtype: object, 'olmosed01': yearID      2015
# teamID       SEA
# lgID          AL
# salary    512500
# Name: olmosed01, dtype: object, 'sucreje01': yearID      2015
# teamID       SEA
# lgID          AL
# salary    509300
# Name: sucreje01, dtype: object, 'tayloch03': yearID      2015
# teamID       SEA
# lgID          AL
# salary    512400
# Name: tayloch03, dtype: object, 'walketa01': yearID      2015
# teamID       SEA
# lgID          AL
# salary    513100
# Name: walketa01, dtype: object, 'duffyma01': yearID      2015
# teamID       SFN
# lgID          NL
# salary    509000
# Name: duffyma01, dtype: object, 'panikjo01': yearID      2015
# teamID       SFN
# lgID          NL
# salary    522500
# Name: panikjo01, dtype: object, 'grichra01': yearID      2015
# teamID       SLN
# lgID          NL
# salary    510000
# Name: grichra01, dtype: object, 'andrima01': yearID      2015
# teamID       TBA
# lgID          AL
# salary    507500
# Name: andrima01, dtype: object, 'beckhti01': yearID      2015
# teamID       TBA
# lgID          AL
# salary    508100
# Name: beckhti01, dtype: object, 'belivje01': yearID      2015
# teamID       TBA
# lgID          AL
# salary    513600
# Name: belivje01, dtype: object, 'boxbebr01': yearID      2015
# teamID       TBA
# lgID          AL
# salary    521400
# Name: boxbebr01, dtype: object, 'colomal01': yearID      2015
# teamID       TBA
# lgID          AL
# salary    510800
# Name: colomal01, dtype: object, 'karnsna01': yearID      2015
# teamID       TBA
# lgID          AL
# salary    508800
# Name: karnsna01, dtype: object, 'kiermke01': yearID      2015
# teamID       TBA
# lgID          AL
# salary    513800
# Name: kiermke01, dtype: object, 'souzast01': yearID      2015
# teamID       TBA
# lgID          AL
# salary    508700
# Name: souzast01, dtype: object, 'yateski01': yearID      2015
# teamID       TBA
# lgID          AL
# salary    512800
# Name: yateski01, dtype: object, 'claudal01': yearID      2015
# teamID       TEX
# lgID          AL
# salary    508500
# Name: claudal01, dtype: object, 'edwarjo02': yearID      2015
# teamID       TEX
# lgID          AL
# salary    508500
# Name: edwarjo02, dtype: object, 'freemsa01': yearID      2015
# teamID       TEX
# lgID          AL
# salary    517000
# Name: freemsa01, dtype: object, 'kleinph01': yearID      2015
# teamID       TEX
# lgID          AL
# salary    509500
# Name: kleinph01, dtype: object, 'martini01': yearID      2015
# teamID       TEX
# lgID          AL
# salary    515000
# Name: martini01, dtype: object, 'mendero01': yearID      2015
# teamID       TEX
# lgID          AL
# salary    509500
# Name: mendero01, dtype: object, 'odorro01': yearID      2015
# teamID       TEX
# lgID          AL
# salary    513850
# Name: odorro01, dtype: object, 'ruary01': yearID      2015
# teamID       TEX
# lgID          AL
# salary    508500
# Name: ruary01, dtype: object, 'smolija01': yearID      2015
# teamID       TEX
# lgID          AL
# salary    508500
# Name: smolija01, dtype: object, 'hynesco01': yearID      2015
# teamID       TOR
# lgID          AL
# salary    510800
# Name: hynesco01, dtype: object, 'norrida01': yearID      2015
# teamID       TOR
# lgID          AL
# salary    508700
# Name: norrida01, dtype: object, 'pillake01': yearID      2015
# teamID       TOR
# lgID          AL
# salary    512000
# Name: pillake01, dtype: object, 'pompeda01': yearID      2015
# teamID       TOR
# lgID          AL
# salary    508500
# Name: pompeda01, dtype: object, 'sanchaa01': yearID       2015
# teamID        TOR
# lgID           AL
# salary    1021600
# Name: sanchaa01, dtype: object, 'stromma01': yearID      2015
# teamID       TOR
# lgID          AL
# salary    514700
# Name: stromma01, dtype: object, 'tollest01': yearID      2015
# teamID       TOR
# lgID          AL
# salary    517300
# Name: tollest01, dtype: object, 'barreaa01': yearID      2015
# teamID       WAS
# lgID          NL
# salary    514200
# Name: barreaa01, dtype: object, 'dendema01': yearID      2015
# teamID       WAS
# lgID          NL
# salary    512972
# Name: dendema01, dtype: object, 'robincl01': yearID      2015
# teamID       WAS
# lgID          NL
# salary    525000
# Name: robincl01, dtype: object, 'taylomi02': yearID      2015
# teamID       WAS
# lgID          NL
# salary    508700
# Name: taylomi02, dtype: object, 'treinbl01': yearID      2015
# teamID       WAS
# lgID          NL
# salary    512800
# Name: treinbl01, dtype: object}

# %% [markdown]
# #### Create Dataframe Using the Constructor

# %% [markdown]
# Read the documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html#pandas.DataFrame and create a dataframe using pd.DataFrame from the dictionary created in the iterrows() exercise. Change the header to "a", "b", "c", ... at creation time.

# %%
df = pd.read_csv("Salaries.csv",header=0,index_col='playerID',skiprows=[1])
dic = {}
for row in df.iterrows():
    dic[row[0]] = row[1]

df2 = pd.DataFrame.from_dict(dic, orient='index',columns = ['a','b','c','d'])
print(df2)
# Out:
#            yearID teamID lgID  salary
# bedrost01    1995    ATL   NL  750000
# benedbr01    1989    ATL   NL  395000
# campri01     1986    ATL   NL  600000
# ceronri01    1992    MON   NL  230000
# chambch01    1986    ATL   NL  769452
# ...           ...    ...  ...     ...
# barreaa01    2015    WAS   NL  514200
# dendema01    2015    WAS   NL  512972
# robincl01    2015    WAS   NL  525000
# taylomi02    2015    WAS   NL  508700
# treinbl01    2015    WAS   NL  512800
#
# [4963 rows x 4 columns]

# %% [markdown]
# ### Numpy

# %% [markdown]
# Quick start: https://www.numpy.org/devdocs/user/quickstart.html
#
# Numpy axes explaination: https://www.sharpsightlabs.com/blog/numpy-axes-explained/

# %% [markdown]
# #### The np.array Method

# %% [markdown]
# Example 1:
#
# ```python
# ls = [1, 2, 3]
# arr = np.array(ls)
# ```
#
# Example 2:
# ```python
# >>> np.array([[1, 2], [3, 4]])
# array([[1, 2],
#        [3, 4]])
# ```

# %% [markdown]
# Now, create a 2-dimensional Python list object, then convert it to a Numpy array object.

# %%
ls = [[1,2],[2,3]]
arr = np.array(ls)

# %% [markdown]
# #### ndarray Objects' Attributes

# %% [markdown]
# Play with the **ndim, shape, size, dtype, itemsize and data** attribute.
#
# Example:
#
# ```python
# >>> arr = np.array([[1, 2], [3, 4]])
# >>> arr.ndim
# 2
# ```

# %%
arr = np.array([[1, 2], [3, 4],[5,6]])
arr.shape
# Out:
# (3, 2)

# %% [markdown]
# #### Dimension of ndarray Ojects

# %% [markdown]
# Play with the reshape() and flatten() method.
#
# Example:
# ```python
# >>> arr = np.array([[1, 2], [3, 4]])
# >>> arr.flatten()
# array([1, 2, 3, 4])
# ```

# %%
arr = np.array([[1, 2,3], [3, 4,5]])
a = arr.reshape(2,3)
print(a)
# Out:
# [[1 2 3]
#  [3 4 5]]

# %% [markdown]
# #### The Slice Operation of ndarray Objects

# %% [markdown]
# Understand how the slice operation works for 1-D array and 2-D array.
#
# Example:
#
# ```python
# >>> arr = np.array([[1, 2, 3], [3, 4, 6], [7, 8, 9]])
# >>> arr[1:]
# array([[3, 4, 6],
#        [7, 8, 9]])
# >>> arr[1:, 0:2]
# array([[3, 4],
#        [7, 8]])
# ```

# %% [markdown]
# #### The Calculation of ndarray Objects

# %% [markdown]
# Play with the **argmin(), argmax(), min(), max(), mean(), sum(), std(), dot(), square(), sqrt(), abs(). exp(), sign(), mod()** method.
#
# Example:
#
# ```python
# >>> np.square(array)
# array([[ 1,  4,  9],
#        [ 9, 16, 36],
#        [49, 64, 81]])
#
# ```

# %%
arr = np.array([[1, 2, 3], [3, 4, 6], [7, 8, 9]])
np.argmax(arr)
# Out:
# 8

# %% [markdown]
# #### Other Important Methods Inside Module Numpy

# %% [markdown]
# Play with the arange(), ones(), zeros(), eye(), linspace(), concatenate() method.
#
# Example:
#
# ```python
# >>> np.eye(3)
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])
# ```

# %%
np.zeros(4)
# Out:
# array([0., 0., 0., 0.])

# %% [markdown]
# ### Scikit-Learn

# %% [markdown]
# The followings are packages (or methods) in Python (Scikit-Learn and Scipy) that will be frequently used in your programming assignment. So, please read carefully.
#
# - Data Preprocessing (https://scikit-learn.org/stable/modules/classes.html#module-sklearn.preprocessing)
#     - Standardization: StandardScaler
#     - Normalization: MinMaxScaler
#     - Quantifing Categorical Features: LabelEncoder. OneHotEncoder
#     - Construct Train and Test Set: model_selection.train_test_split
# - KNN: KNeighborsClassifier
# - Linear Regression: LinearRegression
# - Logistic Regression: LogisticRegression, LogisticRegressionCV
# - Feature Selection / Model Selection
#     - L1 Penalized Regression (Lasso Regression) with Cross-Validation: LassoCV
#     - L2 Penalized Regression (Ridge Regression) with Cross-Validation: RidgeCV
#     - Cross-Validation: StratifiedKFold, RepeatedKFold, LeaveOneOut, KFold, model_selection.cross_validate, model_selection.cross_val_predict, model_selection.cross_val_score
#     - Model Metrics (https://scikit-learn.org/stable/modules/classes.html#sklearn-metrics-metrics): accuracy_score, auc, f1_score, hamming_loss, precision_score, recall_score, roc_auc_score
# - Decision Tree: DecisionTreeClassifier, DecisionTreeRegressor
# - Bootstrap, Ensemble Methods
#     - Bootstrap: bootstrapped (https://pypi.org/project/bootstrapped/)
#     - Bagging: RandomForestClassifier, RandomForestRegressor
#     - Boosting: AdaBoostClassifier, AdaBoostRegressor
# - Support Vector Machines (https://scikit-learn.org/stable/modules/svm.html#svm): LinearSVC, LinearSVR
# - Multiclass and Multilabel Classification (https://scikit-learn.org/stable/modules/classes.html#module-sklearn.multiclass)
#     - One-vs-one Multiclass Strategy: OneVsOneClassifier
#     - One-vs-the-rest (OvR) multiclass/multilabel strategy / OneVsRestClassifier
# - Unsupervised Learning
#     - K-means Clustering: KMeans
#     - Hierarchical Clustering: scipy.cluster.hierarchy (not scikit-learn)
# - Semisupervised Learning (https://scikit-learn.org/stable/modules/label_propagation.html)

# %% [markdown]
# ### Matplotlib

# %% [markdown]
# **Quick start:** https://matplotlib.org/3.1.1/tutorials/introductory/pyplot.html
#
# **Exercises:**

# %% [markdown]
# (a) Create two one dimensional arrays x and y and plot y vs x, add title, xlabel, ylabel, grid.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
#
# x = np.linspace(-5, 5, num=20)
# y = np.array([j ** 2 for j in x])
# ```
#
# copy the code above to the following cell and add code for plotting the parabola.

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(-5, 5, num=20)
y = np.array([j ** 2 for j in x])

# %% [markdown]
# What happens if the independent variable is not sorted before plotting? Try plotting directly using the following defined array.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
#
# x = np.linspace(-5, 5, num=20)
# np.random.shuffle(x)
# y = np.array([j ** 2 for j in x])
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(-5, 5, num=20)
np.random.shuffle(x)
y = np.array([j ** 2 for j in x])
print(y)
# Out:
# [11.70360111 15.58171745  1.73130194  0.06925208 20.01385042  0.06925208
#   0.6232687   0.6232687   1.73130194  8.37950139  3.3933518  20.01385042
#   5.60941828  3.3933518   5.60941828 15.58171745 25.         11.70360111
#  25.          8.37950139]

# %% [markdown]
# (b) Create multiple arrays and plot them with different styles, add legends, add text/mathematical equations on the plot.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
#
# x = np.linspace(-5, 5, num=20)
# y1 = np.array([j for j in x])
# y2 = np.array([j ** 2 for j in x])
# y3 = np.array([j ** 3 for j in x])
# ```
#
# copy the code above to the following cell and add code for plotting curve $\left(x, y1\right)$, $\left(x, y2\right)$ and $\left(x, y3\right)$.

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(-5, 5, num=20)
y1 = np.array([j for j in x])
y2 = np.array([j ** 2 for j in x])
y3 = np.array([j ** 3 for j in x])

plt.plot(x,y1)
plt.xlabel("X")
plt.ylabel("Y1")
plt.show()
plt.plot(x,y2)
plt.xlabel("X")
plt.ylabel("Y2")
plt.show()
plt.plot(x,y3)
plt.xlabel("X")
plt.ylabel("Y3")
plt.show()

# %% [markdown]
# (c) Create multiple arrays and plot them into one figure **(No multiple figure and no subplot is allowed in this question)**.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
#
# x = np.linspace(-5, 5, num=20)
# y1 = np.array([j for j in x])
# y2 = np.array([j ** 2 for j in x])
# y3 = np.array([j ** 3 for j in x])
# ```
#
# copy the code above to the following cell and add code for plotting curve $\left(x, y1\right)$, $\left(x, y2\right)$ and $\left(x, y3\right)$.

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(-5, 5, num=20)
y1 = np.array([j for j in x])
y2 = np.array([j ** 2 for j in x])
y3 = np.array([j ** 3 for j in x])

plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.show()

# %% [markdown]
# (d) Create multiple subplots, play around with the figure size, figure title, and its font style and font size **(One curve is plotted in one subplot in this question)**.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
#
# x = np.linspace(-5, 5, num=20)
# y1 = np.array([j for j in x])
# y2 = np.array([j ** 2 for j in x])
# y3 = np.array([j ** 3 for j in x])
# ```
#
# copy the code above to the following cell and add code for plotting curve $\left(x, y1\right)$, $\left(x, y2\right)$ and $\left(x, y3\right)$.

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(-5, 5, num=20)
y1 = np.array([j for j in x])
y2 = np.array([j ** 2 for j in x])
y3 = np.array([j ** 3 for j in x])

plt.plot(x,y1)
plt.figure(figsize=(2, 2))
plt.plot(x,y2)
plt.title("Test (x,y2)")
plt.show()
plt.plot(x,y3)
plt.xlabel("x",fontsize= 20)
plt.ylabel("y3",fontsize= 16)
plt.show()

# %% [markdown]
# (e) Change the limits on x and y axes, **use logarithmic axes to plot**.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
#
# x = np.linspace(-5, 5, num=20)
# y = np.array([j ** 2 for j in x])
# ```
#
# copy the code above to the following cell and add code for plotting the parabola.

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(-5, 5, num=20)
y = np.array([j ** 2 for j in x])

plt.plot(x,y)
plt.xscale("log")
plt.yscale("log")

# %% [markdown]
# ### Pandas's DataFrame.plot and Seaborn

# %% [markdown]
# #### Pandas's DataFrame.plot
#
# Use the Salaries.csv again (You can use the dataframe object loaded from section 3.1).

# %% [markdown]
# (a) For team 'ATL', plot a scatter plot between feature yearID and salary.

# %%
import seaborn as sns
from matplotlib.axes._axes import _log as matplotlib_axes_logger
matplotlib_axes_logger.setLevel('ERROR')

df = pd.read_csv("Salaries.csv",header=0,index_col='playerID',skiprows=[1])
data1 = df[df.teamID == 'ATL']

data1.plot.scatter(x="yearID", y="salary",alpha=0.8)
# Out:
# <AxesSubplot:xlabel='yearID', ylabel='salary'>

# %% [markdown]
# (b) For year 1985, plot a bar chart to show the average salary for each team.

# %%
df = pd.read_csv("Salaries.csv",header=0,index_col='playerID',skiprows=[1])
data1 = df[df.yearID == 1985]
data2 = data1['teamID'].unique()
data3 = []
for i in data2:
    data4 = df[(df.yearID == 1985) & (df.teamID == i)]
    data3.append(data4['salary'].mean())
    
plt.figure(figsize=(6, 6))
plt.plot_date(data2, data3)

# %% [markdown]
# (c) For team 'ATL', plot a line chart to show how the annual average salary change by years.

# %%
df = pd.read_csv("Salaries.csv",header=0,index_col='playerID',skiprows=[1])
data1 = df[df.teamID == 'ATL']
data2 = data1['yearID'].unique()
data3 = []
for i in data2:
    data4 = df[df.yearID == i]
    data3.append(data4['salary'].mean())
    
plt.figure(figsize=(6, 6))
plt.plot(data2, data3)

# %% [markdown]
# #### Seaborn

# %% [markdown]
# (a) Append one more numeric feature to the data frame (can be generated randomly), then for team 'ATL', use the seaborn.pairplot to plot scatter plots among all numeric features in the data frame for team.

# %%
import random

df = pd.read_csv("Salaries.csv",header=0,index_col='playerID',skiprows=[1])
data1 = df[df.teamID == 'ATL']
data1["append_num"] = np.random.randint(5,30,size=885)
data1 = data1.drop(columns = ['teamID','lgID'])

sns.pairplot(data=data1)
# Out:
# <ipython-input-72-6fdeff818134>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["append_num"] = np.random.randint(5,30,size=885)

# %% [markdown]
# (b) For year 1985 and for each team, plot a boxplot to show how the salary distribute within a team.

# %%
df = pd.read_csv("Salaries.csv",header=0,index_col='playerID',skiprows=[1])
data1 = df[df.yearID == 1985]
data2 = data1['teamID'].unique()

ax = sns.boxplot(x='teamID', y='salary', data=data1)

# %% [markdown]
# (c) Read the offical documentation (https://seaborn.pydata.org/) to understand how lmplot, catplot, relplot, and jointplot works.

# %% [markdown]
# ### Jupyter Notebook

# %% [markdown]
# #### Jupyter Notebook Extensions

# %% [markdown]
# Extensions such as the code formatter, table of content is to make your development more efficient. To explore it, please refer to https://github.com/ipython-contrib/jupyter_contrib_nbextensions.

# %% [markdown]
# #### Jupyter Visual Debugger

# %% [markdown]
# The Pixie Debugger is a visual debugger for debugging on Jupyter Notebook. To explore it, please refer to https://medium.com/codait/the-visual-python-debugger-for-jupyter-notebooks-youve-always-wanted-761713babc62.

# %% [markdown]
# ### Git and GitHub

# %% [markdown]
# 1. In the directory that where this jupyter notebook file locates in, init a Git repository.
# 2. Checkout a new branch called dev and commit the current notebook within this branch.
# 3. Merge the dev branch to the master branch (the default branch).
# 4. Create a temporary repository (just for practicing and you can delete it later) in GitHub.
# 5. Push new changes in the master branch to the remote repository created in step 4.
# 6. Checkout the dev branch again and do some changes to your notebook, and then repeat step 3 and step 5.
